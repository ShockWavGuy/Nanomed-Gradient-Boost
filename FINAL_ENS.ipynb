# %%
import pandas as pd
import numpy as np
import catboost as cb
import re

data = pd.read_csv("datasetCELL.csv", index_col=None)
data2 = pd.read_csv("datasetCELL2.csv", index_col=None)

def clean_col(s):
    return s.astype(str).str.lower().str.strip()

for col in data.select_dtypes(include=['object', 'category']).columns:
    data[col] = clean_col(data[col])


organic_families = [
    'liposome', 'thermosensitive liposome', 'cationic liposome',
    'solid lipid nanoparticles', 'polymer-based nanoparticles',
    'albumin nanoparticles', 'dendrimer', 'micelle',
    'extracellular vesicles'
]



inorganic_families = ['magnetic liposome', 'gold nanoparticles','magnetic nanoparticles', 'inorganic nanoparticles']

organic_families2 = ['polymer-based nanoparticles']




data = data.rename(columns={'EE%': 'EE'})
data['group'] = data2['group'].astype(str)
print(data['group'].isnull().sum())

for col in data.columns:
    if data[col].dtype == 'object':
        data[col] = data[col].str.lower().str.strip()

data = data.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
data = data[data['prep'].isin(organic_families)]

print(data['prep'].unique())


print(data.columns)
print(data.drugcarrierratio)
data['group']
# Out:
# 0
# ['liposome' 'thermosensitive liposome' 'cationic liposome'
#  'solid lipid nanoparticles' 'polymer-based nanoparticles'
#  'albumin nanoparticles' 'dendrimer' 'micelle' 'extracellular vesicles']
# Index(['prep', 'comp', 'PEG', 'PEGRatio', 'surfacecoating', 'ligandtype',
#        'ligand', 'mechanism', 'receptortype', 'receptor', 'Pgp',
#        'Pgpinhibitor', 'size', 'PDI', 'zeta', 'EE', 'DL', 'animalmodel',
#        'route', 'liganddensitymol', 'liganddensitynum', 'encapsulation',
#        'external', 'ID', 'drugcarrierratio', 'modratiounmod', 'charge',
#        'exact_mass', 'xlogp', 'tpsa', 'atom_stereo_count', 'bond_stereo_count',
#        'h_bond_donor_count', 'h_bond_acceptor_count', 'rotatable_bond_count',
#        'heavy_atom_count', 'complexity', 'charge1', 'exact_mass1', 'xlogp1',
#        'tpsa1', 'atom_stereo_count1', 'bond_stereo_count1',
#        'h_bond_donor_count1', 'h_bond_acceptor_count1',
#        'rotatable_bond_count1', 'heavy_atom_count1', 'complexity1', 'group'],
#       dtype='object')
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 643         NaN
# 646    1.594203
# 647    2.739130
# 649    1.940000
# 650    3.540000
# Name: drugcarrierratio, Length: 390, dtype: float64
# 0         1
# 1         1
# 2         2
# 3         4
# 4         4
#        ...
# 643    1373
# 646    1376
# 647    1376
# 649    1405
# 650    1405
# Name: group, Length: 390, dtype: object

# %%
from GradientBoost import cv_regression_catboost, prep_dataset, tune_catboost_with_optuna, cv_regression_lgbm, ensemble
import re

data = data.dropna(subset=['ID'])
data = data[data['ID'] > 0].copy()
data['logID'] = np.log(data['ID'])
data['logDCR'] = np.log(data['drugcarrierratio'])
#data['binID'] = (data['ID'] > 0.05).astype(int)
data = data[np.isfinite(data['logID'])].copy()
target_col = 'logID'
group = 'group'

data = data.dropna(subset=[target_col])

#data['is_dual_ligand'] = data['ligand'].str.contains(r'and|/|\+', case=False)

def peptide_charge(x):
    x = str(x).upper()
    count = x.count('R') + x.count('K')
    if count >= 5: return 'high_cationic'
    if count >= 2: return 'medium_cationic'
    return 'neutral'
    
#data['ligand_charge'] = data['ligand'].apply(peptide_charge)


def peptide_length(x):
    seq = re.findall(r'[A-Z]{2,}', x.replace(' ', '').upper())
    if not seq:
        return 0
    return sum(len(s) for s in seq)

#data['ligand_peptide_length'] = data['ligand'].fillna('').apply(peptide_length)
#data['has_PEG'] = data['ligand'].str.contains('PEG', case=False)

# %%
feat_cols = ['prep', 'comp', 'PEG', 'PEGRatio', 'surfacecoating', 'ligandtype',
       'ligand', 'mechanism', 'receptortype', 'receptor', 
       'size', 'PDI', 'zeta', 'EE', 'DL', 'animalmodel',
       'route', 'liganddensitymol',
       'external', 
       'exact_mass', 'xlogp', 'tpsa', 'atom_stereo_count', 
       'h_bond_donor_count', 'h_bond_acceptor_count', 'rotatable_bond_count',
       'heavy_atom_count', 'complexity', 'xlogp1']
cat_cols = [f for f in feat_cols if data[f].dtype == 'object']


efflux_unc = pd.read_csv("efflux_uncertain.csv")
efflux = pd.read_csv("efflux.csv")
morgan = pd.read_csv("morgan.csv")

efflux = efflux_unc.drop(['Name','Original SMILES'], axis=1)
eff_rel = [
    'PGP_substrate',      # P-glycoprotein - PRIMARY BBB efflux pump
    'BCRP_substrate',     # BCRP/ABCG2 - Major BBB efflux pump  
    'PGP_inhibitor',      # P-gp inhibition can improve brain delivery
    'BCRP_inhibitor',     # BCRP inhibition can improve brain delivery
    'MRP1_substrate',     # MRP1 - Secondary BBB efflux pump
    'MRP1_inhibitor'      # MRP1 inhibition effect
]
#morg = [str(x) for x in range(2048)]
#morg2 = [str(x)+" morgan" for x in range(2048)]

data[eff_rel] = efflux[eff_rel]
#data = pd.concat([data,morgan[morg_rel]], axis=1)

feat_cols = ['prep', 'comp', 'PEG', 'PEGRatio', 'surfacecoating', 'ligandtype',
       'ligand', 'mechanism', 'receptortype', 'receptor', 'Pgp',
       'size', 'PDI', 'zeta', 'EE', 'DL', 'animalmodel',
       'route', 'liganddensitymol',
       'external', 
       'exact_mass', 'xlogp', 'tpsa', 'atom_stereo_count', 
       'h_bond_donor_count', 'h_bond_acceptor_count', 'rotatable_bond_count',
       'heavy_atom_count', 'complexity', 'xlogp1']

feat_cols = feat_cols + eff_rel

cat_df = prep_dataset(data, target_col=target_col, one_hot=False, feat=feat_cols,cat=cat_cols, group_col=group)
lgbm_df = prep_dataset(data, target_col=target_col, one_hot=True, feat=feat_cols,cat=cat_cols, group_col=group)
lgbm_df = lgbm_df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
lgbm_df = lgbm_df.loc[:, ~lgbm_df.columns.duplicated()].copy()
lgbm_feats = [c for c in lgbm_df.columns if c != group and c!=target_col]

#print(lgbm_df.columns)
cat_df.to_csv('the_supreme.csv')

print(len(data['encapsulation'].unique()))
# Out:
# 110

# %%
from variance_decomposition import decompose_variance

result = decompose_variance(
        df            = lgbm_df,
        target_col    = target_col,
        group_col     = group,
        feature_cols  = lgbm_feats,
        min_group_size = 2,
        save_plot     = True,
        save_excel    = False,
    )
# Out:
#   Excluding 46 groups with <2 samples (46 rows removed).
#
# ============================================================
#   Variance Decomposition Setup
# ============================================================
#   Samples:  338
#   Groups:   112
#   Features: 350
#   Target:   logID
#   Method:   Linear Mixed Effects (REML)
# ============================================================
#
#   [1/3] Decomposing TARGET variance...
#         ICC = 0.414 (41.4% between-group)
#         📊 MODERATE ICC: logID has meaningful study variation.
#            Group-aware modeling recommended.
#
#   [2/3] Computing ICC for 350 features...
#         5/350 done...
#         10/350 done...
#         15/350 done...
#         20/350 done...
#         25/350 done...
#         30/350 done...
#         35/350 done...
#         40/350 done...
#         45/350 done...
#         55/350 done...
#         60/350 done...
#         65/350 done...
#         70/350 done...
#         75/350 done...
#         80/350 done...
#         85/350 done...
#         90/350 done...
#         95/350 done...
#         105/350 done...
#         110/350 done...
#         115/350 done...
#         120/350 done...
#         130/350 done...
#         135/350 done...
#         140/350 done...
#         145/350 done...
#         150/350 done...
#         155/350 done...
#         160/350 done...
#         165/350 done...
#         170/350 done...
#         180/350 done...
#         185/350 done...
#         190/350 done...
#         195/350 done...
#         200/350 done...
#         205/350 done...
#         210/350 done...
#         215/350 done...
#         220/350 done...
#         225/350 done...
#         230/350 done...
#         235/350 done...
#         240/350 done...
#         245/350 done...
#         250/350 done...
#         255/350 done...
#         260/350 done...
#         265/350 done...
#         270/350 done...
#         275/350 done...
#         280/350 done...
#         285/350 done...
#         290/350 done...
#         295/350 done...
#         300/350 done...
#         305/350 done...
#         310/350 done...
#         315/350 done...
#         320/350 done...
#         325/350 done...
#         330/350 done...
#         335/350 done...
#         340/350 done...
#         345/350 done...
#         350/350 done...
#
#   [3/3] Testing fixed effects on target...
#
# ============================================================
#   DECOMPOSITION SUMMARY
# ============================================================
#   Target ICC:  0.414  (41.4% between-group)
#   → moderate — meaningful study effect
#
#   Features with high ICC (≥0.5): 69
#     - comp_pamamg4: ICC=1.000
#     - mechanism_transcytosis: ICC=1.000
#     - comp_epcdspepeg: ICC=1.000
#     - comp_dspepeg2000: ICC=1.000
#     - comp_polyethyleneglycolblockpoly2methyl2benzoxycarbonylpropylenecarbonate: ICC=1.000
#
#   Significant within-group predictors: 0
#
#   ISEF ANCHOR FINDING:
#   Study/group identity alone explains 41.4% of the variance in logID (ICC=0.414), before considering any formulation features. The most study-dominated feature is 'comp_pamamg4' (ICC=1.000). After controlling for study effects, 'no significant features' shows the strongest within-group predictive signal.
# ============================================================
#
# ============================================================
#   VARIANCE DECOMPOSITION REPORT
# ============================================================
#
# ── TARGET: logID ──
#   ICC  = 0.4145
#   Between-group variance: 41.4%
#   Within-group variance:  58.6%
#   Interpretation: moderate — meaningful study effect
#
#   → 41.4% of logID variance is explained by study/group identity alone,
#     before considering ANY formulation features.
#
# ── FEATURE ICCs (top 15) ──
# Feature                                ICC   Between%  Interpretation
# ---------------------------------------------------------------------------
# comp_pamamg4                         1.000     100.0%  very large — feature dominated by study
# mechanism_transcytosis               1.000     100.0%  very large — feature dominated by study
# comp_epcdspepeg                      1.000     100.0%  very large — feature dominated by study
# comp_dspepeg2000                     1.000     100.0%  very large — feature dominated by study
# comp_polyethyleneglycolblockpoly2methyl2benzoxycarbonylpropylenecarbonate  1.000     100.0%  very large — feature dominated by study
# comp_polybutylcyanoacrylate          1.000     100.0%  very large — feature dominated by study
# comp_phospholipidcholestrolquantumdot  1.000     100.0%  very large — feature dominated by study
# ligand_ascorbicacid                  1.000     100.0%  very large — feature dominated by study
# receptor_sodiumdependentvitaminctransporters  1.000     100.0%  very large — feature dominated by study
# comp_bovineserumalbumin              1.000     100.0%  very large — feature dominated by study
# comp_dspepeg1000maleimide            1.000     100.0%  very large — feature dominated by study
# comp_glycerylmonostearateglycerolpolyoxyethyleneglycolpalmitostearat  1.000     100.0%  very large — feature dominated by study
# comp_dopedotapcholesterol            1.000     100.0%  very large — feature dominated by study
# comp_nbutylcyanoacrylate             1.000     100.0%  very large — feature dominated by study
# ligand_hthrbzlphephetyrbrzglyglyserbzlargtosglylysclzargtosasnxanasnxanphelysclzthrbzlgluochexgluochextyrbrzcyspmebzloh  1.000     100.0%  very large — feature dominated by study
#
# ── FIXED EFFECTS ON TARGET (within-group signal, top 15) ──
# Feature                                Coef    p-value   R²_marg  Sig
# ---------------------------------------------------------------------------
# PEG                                    nan        nan       nan
# PEGRatio                               nan        nan       nan
# Pgp                                    nan        nan       nan
# size                                   nan        nan       nan
# PDI                                    nan        nan       nan
# zeta                                   nan        nan       nan
# EE                                     nan        nan       nan
# DL                                     nan        nan       nan
# liganddensitymol                       nan        nan       nan
# exact_mass                             nan        nan       nan
# xlogp                                  nan        nan       nan
# tpsa                                   nan        nan       nan
# atom_stereo_count                      nan        nan       nan
# h_bond_donor_count                     nan        nan       nan
# h_bond_acceptor_count                  nan        nan       nan
#
#   Significance: *** p<0.01  * p<0.05
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 from variance_decomposition import decompose_variance
# ----> 3 result = decompose_variance(
#       4         df            = lgbm_df,
#       5         target_col    = target_col,
#       6         group_col     = group,
#       7         feature_cols  = lgbm_feats,
#       8         min_group_size = 2,
#       9         save_plot     = True,
#      10         save_excel    = False,
#      11     )
#
# File ~/Documents/science fair/variance_decomposition.py:726, in decompose_variance(df, target_col, group_col, feature_cols, min_group_size, save_plot, save_excel, verbose)
#     724 vd.report()
#     725 if save_plot:
# --> 726     vd.plot()
#     727 if save_excel:
#     728     vd.to_excel()
#
# File ~/Documents/science fair/variance_decomposition.py:575, in VarianceDecomposer.plot(self, save_path, figsize)
#     573     print(f"\n  Plot saved to: {save_path}")
#     574 else:
# --> 575     plt.savefig("/mnt/user-data/outputs/variance_decomposition_plot.png",
#     576                 dpi=150, bbox_inches="tight")
#     577     print("  Plot saved to: /mnt/user-data/outputs/"
#     578           "variance_decomposition_plot.png")
#     579 plt.close()
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/PIL/Image.py:2566, in Image.save(self, fp, format, **params)
#    2564         fp = builtins.open(filename, "r+b")
#    2565     else:
# -> 2566         fp = builtins.open(filename, "w+b")
#    2567 else:
#    2568     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/user-data/outputs/variance_decomposition_plot.png'

# %%
from recycling_v14 import TrainConfig, run_training_from_df

lgbm_feats = [c for c in lgbm_df.columns if c != group and c!=target_col]
cfg = TrainConfig(
        epochs=4000, patience=25, post_graph_patience=60,
        rebuild_adj_start=60, min_study_size=5,
        num_iterations=10, mask_rate=0.15,
        mice_max_iter=10, mice_epochs=100,
        max_missing_pct=0.80,
    )

out = run_training_from_df(lgbm_df, target_col, group, lgbm_feats, n_splits=5, cfg=cfg, ablate=True)
print("\n=== Summary ===")
print(f"\n  Hybrid  RMSE : {out['avg_rmse']:.4f} ± {out['std_rmse']:.4f}  "
              f"R²={out['avg_r2']:.4f}")
print(f"  CatBoost  RMSE : {out['avg_rmse_cb_only']:.4f}  "
      f"R²={out['avg_r2_cb_only']:.4f}")

smoketest()
# Out:
#   [Data] Dropping 3 columns >80% missing: ['DL', 'liganddensitymol', 'xlogp1']
#
# Missingness summary (347 cont features, 0 cat features):
#   PEG: 3.1%
#   PEGRatio: 63.3%
#   Pgp: 45.3%
#   size: 17.4%
#   PDI: 48.7%
#   zeta: 32.6%
#   EE: 61.5%
#   exact_mass: 33.1%
#   xlogp: 39.3%
#   tpsa: 33.1%
#   atom_stereo_count: 33.1%
#   h_bond_donor_count: 33.1%
#   h_bond_acceptor_count: 33.1%
#   rotatable_bond_count: 33.1%
#   heavy_atom_count: 33.1%
#   complexity: 33.1%
#
# [Fold 1] Large=12 | Test seen_large=0 unseen=77
#   [Fold 1] Fitting MICE imputer...
#   [Early stop epoch 50] best_val=1.1102
# [Fold 1/5] RMSE=2.8832 MAE=2.4894 R²=-0.2649 | Phase1=3.3378
#
# [Fold 2] Large=11 | Test seen_large=0 unseen=77
#   [Fold 2] Fitting MICE imputer...
#   [Epoch 60] Graph built (11 studies).
#   [Graph] 1/11 isolated studies — self-loop only.
#   [Early stop epoch 170] best_val=1.2596
# [Fold 2/5] RMSE=3.2195 MAE=2.6884 R²=-0.7554 | Phase1=3.2091
#
# [Fold 3] Large=11 | Test seen_large=0 unseen=77
#   [Fold 3] Fitting MICE imputer...
#   [Epoch 60] Graph built (11 studies).
#   [Early stop epoch 106] best_val=1.1432
# [Fold 3/5] RMSE=2.8648 MAE=2.2692 R²=-0.7064 | Phase1=3.3825
#
# [Fold 4] Large=11 | Test seen_large=0 unseen=77
#   [Fold 4] Fitting MICE imputer...
#   [Early stop epoch 59] best_val=2.0199
# [Fold 4/5] RMSE=2.5434 MAE=2.0424 R²=-0.3735 | Phase1=3.5844
#
# [Fold 5] Large=11 | Test seen_large=0 unseen=76
#   [Fold 5] Fitting MICE imputer...
#   [Graph] 1/11 isolated studies — self-loop only.
#   [Epoch 60] Graph built (11 studies).
#   [Graph] 1/11 isolated studies — self-loop only.
#   [Graph] 2/11 isolated studies — self-loop only.
#   [Early stop epoch 124] best_val=0.5635
# [Fold 5/5] RMSE=2.3394 MAE=1.8595 R²=-0.1277 | Phase1=3.8355
#
# === Summary ===
#
#   Hybrid  RMSE : 2.7701 ± 0.3035  R²=-0.4456
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 16
#      13 print("\n=== Summary ===")
#      14 print(f"\n  Hybrid  RMSE : {out['avg_rmse']:.4f} ± {out['std_rmse']:.4f}  "
#      15               f"R²={out['avg_r2']:.4f}")
# ---> 16 print(f"  CatBoost  RMSE : {out['avg_rmse_cb_only']:.4f}  "
#      17       f"R²={out['avg_r2_cb_only']:.4f}")
#      19 smoketest()
#
# KeyError: 'avg_rmse_cb_only'

# %%
results_cat = cv_regression_catboost(
    df=cat_df,
    target_col=target_col,
    cat_cols=cat_cols,
    feature_cols=feat_cols+[group],
    use_lmem_cleaning=False,
    cv_type="kfold",
    binary=False,
    group_col=None,
    n_splits=5,
    iterat=6000, learn=0.04987715801619947, dep=7,rand=42, leaf_reg=6.4038007118811135, rand_str=0.15167836674283808, bag_temp=0.3798466046212996, min_d=10, boot="Bayesian", 
    
)
# Out:
# [CatBoost CV] Fold 1
# trained!
# diddy: r2=0.9113508916150095
# predicted!
# R2=0.471, RMSE=1.772, MAE=1.365, Rho=0.674, pval=1.850e-11
#
# [CatBoost CV] Fold 2
# trained!
# diddy: r2=0.928994591132654
# predicted!
# R2=0.477, RMSE=1.882, MAE=1.405, Rho=0.675, pval=1.663e-11
#
# [CatBoost CV] Fold 3
# trained!
# diddy: r2=0.886125792900302
# predicted!
# R2=0.576, RMSE=1.609, MAE=1.179, Rho=0.765, pval=5.922e-16
#
# [CatBoost CV] Fold 4
# trained!
# diddy: r2=0.9006405499666664
# predicted!
# R2=0.516, RMSE=1.598, MAE=1.236, Rho=0.741, pval=1.282e-14
#
# [CatBoost CV] Fold 5
# trained!
# diddy: r2=0.9157698202654032
# predicted!
# R2=0.413, RMSE=1.449, MAE=1.077, Rho=0.647, pval=2.695e-10
#
# [CatBoost CV] Overall:
# R2 mean=0.491 ± 0.054
# RMSE mean=1.662 ± 0.150
# MAE  mean=1.252 ± 0.120
# Rho  mean=0.700 ± 0.045
# AUROC  mean=nan ± nan
# /Users/taha/miniconda3/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/taha/miniconda3/lib/python3.13/site-packages/numpy/_core/_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/taha/miniconda3/lib/python3.13/site-packages/numpy/_core/_methods.py:222: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/taha/miniconda3/lib/python3.13/site-packages/numpy/_core/_methods.py:180: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /Users/taha/miniconda3/lib/python3.13/site-packages/numpy/_core/_methods.py:214: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
models = results_cat['models']
fi = np.mean([model.get_feature_importance() for model in models], axis=0)
print(len(fi), len(feat_cols))

# Build dataframe
fi_df = (
    pd.DataFrame({
        "Feature": feat_cols+[group],
        "Importance": fi
    })
    .sort_values("Importance", ascending=False)
    .reset_index(drop=True)
)

fi_df
# Out:
# 37 36
#                   Feature  Importance
# 0                    size   11.824538
# 1                   group   10.168439
# 2                PEGRatio    8.214317
# 3             animalmodel    7.417422
# 4                    zeta    6.292335
# 5                    comp    5.263342
# 6                    prep    4.984151
# 7                   xlogp    4.127446
# 8                     PDI    3.921358
# 9               mechanism    3.487980
# 10                     EE    3.349485
# 11                  route    2.621685
# 12             ligandtype    2.360985
# 13           receptortype    2.287340
# 14                     DL    2.150965
# 15                 ligand    1.978786
# 16      atom_stereo_count    1.963297
# 17                    Pgp    1.849299
# 18                   tpsa    1.809864
# 19       heavy_atom_count    1.270332
# 20               external    1.266615
# 21             complexity    1.241207
# 22  h_bond_acceptor_count    1.230391
# 23     h_bond_donor_count    1.208614
# 24   rotatable_bond_count    1.143666
# 25             exact_mass    1.138987
# 26         MRP1_inhibitor    0.706348
# 27          PGP_substrate    0.700255
# 28                    PEG    0.649457
# 29       liganddensitymol    0.593845
# 30         surfacecoating    0.555379
# 31               receptor    0.536298
# 32         MRP1_substrate    0.488403
# 33         BCRP_inhibitor    0.455554
# 34                 xlogp1    0.412728
# 35          PGP_inhibitor    0.169823
# 36         BCRP_substrate    0.159062

# %%
#0.04987715801619947
results_ens = ensemble(
    catdf = cat_df,
    lgbmdf = lgbm_df,
    target_col=target_col,
    cat_cols=cat_cols,
    group_col=None,
    n_splits=5,
    #Catboost
    iterat=2920, learn1=0.04987715801619947, dep=7, rand1=42,
    leaf_reg=6.4038007118811135, rand_str=0.15167836674283808, bag_temp=0.3798466046212996, min_d=10, boot="Bayesian",
    #LGBM
    n_est=2977,learn2=0.11127804361710134,max_d=9,sub=0.7287063461374701,col=0.47137369806209434,rand2=42,
    #Verbosity
    verbose=True)
    



results_lgbm = cv_regression_lgbm(
    df=lgbm_df,              # e.g. from prep_dataset(..., one_hot=True)
    target_col=target_col,
    cv_type="kfold",
    group_col=None,
    n_splits=5,
    n_est=977,learn=0.11127804361710134,max_d=9,sub=0.7287063461374701,col=0.47137369806209434,rand=42
)

r2 = np.mean(results_cat['r2_scores'])

print(data[target_col].max() - data[target_col].min())
# Out:
# [CV] Using KFold
#
# [Ensemble CV] Fold 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 2
#       1 #0.04987715801619947
# ----> 2 results_ens = ensemble(
#       3     catdf = cat_df,
#       4     lgbmdf = lgbm_df,
#       5     target_col=target_col,
#       6     cat_cols=cat_cols,
#       7     group_col=None,
#       8     n_splits=5,
#       9     #Catboost
#      10     iterat=2920, learn1=0.04987715801619947, dep=7, rand1=42,
#      11     leaf_reg=6.4038007118811135, rand_str=0.15167836674283808, bag_temp=0.3798466046212996, min_d=10, boot="Bayesian",
#      12     #LGBM
#      13     n_est=2977,learn2=0.11127804361710134,max_d=9,sub=0.7287063461374701,col=0.47137369806209434,rand2=42,
#      14     #Verbosity
#      15     verbose=True)
#      20 results_lgbm = cv_regression_lgbm(
#      21     df=lgbm_df,              # e.g. from prep_dataset(..., one_hot=True)
#      22     target_col=target_col,
#    (...)     26     n_est=977,learn=0.11127804361710134,max_d=9,sub=0.7287063461374701,col=0.47137369806209434,rand=42
#      27 )
#      29 r2 = np.mean(results_cat['r2_scores'])
#
# File ~/Documents/science fair/GradientBoost.py:873, in ensemble(catdf, lgbmdf, target_col, cat_cols, group_col, binary, n_splits, iterat, learn1, dep, rand1, leaf_reg, rand_str, bag_temp, min_d, boot, loss_function, n_est, learn2, max_d, sub, col, rand2, verbose)
#     867 # Fit
#     868 model_cat.fit(
#     869     X_cat_train,
#     870     y_train_fold,
#     871     cat_features=cat_feature_indices,
#     872 )
# --> 873 model_lgbm.fit(X_lgbm_train, y_train_fold)
#     875 # Predict + mean ensemble
#     876 p1 = np.ravel(model_cat.predict(X_cat_val))
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/sklearn.py:1398, in LGBMRegressor.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1381 def fit(  # type: ignore[override]
#    1382     self,
#    1383     X: _LGBM_ScikitMatrixLike,
#    (...)   1395     init_model: Optional[Union[str, Path, Booster, LGBMModel]] = None,
#    1396 ) -> "LGBMRegressor":
#    1397     """Docstring is inherited from the LGBMModel."""
# -> 1398     super().fit(
#    1399         X,
#    1400         y,
#    1401         sample_weight=sample_weight,
#    1402         init_score=init_score,
#    1403         eval_set=eval_set,
#    1404         eval_names=eval_names,
#    1405         eval_sample_weight=eval_sample_weight,
#    1406         eval_init_score=eval_init_score,
#    1407         eval_metric=eval_metric,
#    1408         feature_name=feature_name,
#    1409         categorical_feature=categorical_feature,
#    1410         callbacks=callbacks,
#    1411         init_model=init_model,
#    1412     )
#    1413     return self
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/engine.py:297, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     295 # construct booster
#     296 try:
# --> 297     booster = Booster(params=params, train_set=train_set)
#     298     if is_valid_contain_train:
#     299         booster.set_train_data_name(train_data_name)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/basic.py:3656, in Booster.__init__(self, params, train_set, model_file, model_str)
#    3649     self.set_network(
#    3650         machines=machines,
#    3651         local_listen_port=params["local_listen_port"],
#    3652         listen_time_out=params.get("time_out", 120),
#    3653         num_machines=params["num_machines"],
#    3654     )
#    3655 # construct booster object
# -> 3656 train_set.construct()
#    3657 # copy the parameters from train_set
#    3658 params.update(train_set.get_params())
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/basic.py:2590, in Dataset.construct(self)
#    2585             self._set_init_score_by_predictor(
#    2586                 predictor=self._predictor, data=self.data, used_indices=used_indices
#    2587             )
#    2588 else:
#    2589     # create train
# -> 2590     self._lazy_init(
#    2591         data=self.data,
#    2592         label=self.label,
#    2593         reference=None,
#    2594         weight=self.weight,
#    2595         group=self.group,
#    2596         init_score=self.init_score,
#    2597         predictor=self._predictor,
#    2598         feature_name=self.feature_name,
#    2599         categorical_feature=self.categorical_feature,
#    2600         params=self.params,
#    2601         position=self.position,
#    2602     )
#    2603 if self.free_raw_data:
#    2604     self.data = None
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/basic.py:2123, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, feature_name, categorical_feature, params, position)
#    2121     categorical_feature = reference.categorical_feature
#    2122 if isinstance(data, pd_DataFrame):
# -> 2123     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(
#    2124         data=data,
#    2125         feature_name=feature_name,
#    2126         categorical_feature=categorical_feature,
#    2127         pandas_categorical=self.pandas_categorical,
#    2128     )
#    2129 elif _is_pyarrow_table(data) and feature_name == "auto":
#    2130     feature_name = data.column_names
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/basic.py:868, in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     864 df_dtypes.append(np.float32)
#     865 target_dtype = np.result_type(*df_dtypes)
#     867 return (
# --> 868     _pandas_to_numpy(data, target_dtype=target_dtype),
#     869     feature_name,
#     870     categorical_feature,
#     871     pandas_categorical,
#     872 )
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/basic.py:814, in _pandas_to_numpy(data, target_dtype)
#     810 def _pandas_to_numpy(
#     811     data: pd_DataFrame,
#     812     target_dtype: "np.typing.DTypeLike",
#     813 ) -> np.ndarray:
# --> 814     _check_for_bad_pandas_dtypes(data.dtypes)
#     815     try:
#     816         # most common case (no nullable dtypes)
#     817         return data.to_numpy(dtype=target_dtype, copy=False)
#
# File ~/miniconda3/lib/python3.13/site-packages/lightgbm/basic.py:805, in _check_for_bad_pandas_dtypes(pandas_dtypes_series)
#     799 bad_pandas_dtypes = [
#     800     f"{column_name}: {pandas_dtype}"
#     801     for column_name, pandas_dtype in pandas_dtypes_series.items()
#     802     if not _is_allowed_numpy_dtype(pandas_dtype.type)
#     803 ]
#     804 if bad_pandas_dtypes:
# --> 805     raise ValueError(
#     806         f"pandas dtypes must be int, float or bool.\nFields with bad pandas dtypes: {', '.join(bad_pandas_dtypes)}"
#     807     )
#
# ValueError: pandas dtypes must be int, float or bool.
# Fields with bad pandas dtypes: group: object

# %%
from GradientBoost import cv_gpboost_native_compat

family = [
 'polymer-based nanoparticles']
cat_df_cp = cat_df[cat_df['prep'].isin(family)]


results_gp = cv_gpboost_native_compat(
    df=cat_df,
    target_col=target_col,
    cat_cols=cat_cols,
    cv_type="kfold",
    group_col=group,
    binary=False,
    n_splits=5,
    feature_cols=None,
    # training params
    num_boost_round=40000,
    learning_rate=0.05,
    max_depth=16,
    num_leaves=None,
    min_data_in_leaf=10,
    lambda_l2=10,
    feature_fraction=1,
    bagging_fraction=1,
    seed=42,
    early_stopping_rounds=100,
    approx="vecchia",
    # LMEM cleaning
    use_lmem_cleaning=False,
    lmem_fixed_effects=None,
    lmem_reml=True,
    lmem_verbose=False,
    # likelihood
    likelihood="gaussian",
    verbose=True,
)

data['logID'].max() - data['logID'].min()
# Out:
# [GPBoost CV] Fold 1
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1858: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1564: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1375: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [GPBoost] [Warning] Unknown parameter: pred_response
# R2=0.446, RMSE=1.813, MAE=1.362, Rho=0.639, pval=4.130e-10
#
# [GPBoost CV] Fold 2
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1858: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1564: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1375: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [GPBoost] [Warning] Unknown parameter: pred_response
# R2=0.476, RMSE=1.885, MAE=1.424, Rho=0.709, pval=5.372e-13
#
# [GPBoost CV] Fold 3
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1858: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1564: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1375: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [GPBoost] [Warning] Unknown parameter: pred_response
# R2=0.524, RMSE=1.705, MAE=1.257, Rho=0.720, pval=1.612e-13
#
# [GPBoost CV] Fold 4
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1858: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1564: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1375: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [GPBoost] [Warning] Unknown parameter: pred_response
# R2=0.535, RMSE=1.566, MAE=1.128, Rho=0.737, pval=2.268e-14
#
# [GPBoost CV] Fold 5
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1858: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1564: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/taha/miniconda3/lib/python3.13/site-packages/gpboost/basic.py:1375: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [GPBoost] [Warning] Unknown parameter: pred_response
# R2=0.279, RMSE=1.606, MAE=1.128, Rho=0.572, pval=6.557e-08
#
# [GPBoost CV] Overall:
# R2   mean=0.452 ± 0.092
# RMSE mean=1.715 ± 0.121
# MAE  mean=1.260 ± 0.120
# Rho  mean=0.675 ± 0.061
# np.float64(12.91603370896966)

# %%
from dataset_handling import augment_with_noise
cont_cols = ['size','zeta','EE','DL','PDI']

data_noised = augment_with_noise(
    cat_df,
    cont_cols,
    n_copies=2,
    rel_noise=None,
    abs_noise=None,
    clip_bounds=None,
    base_weight=0.4,
    noise_weight=1,
    random_state=42,
)[0]

data_noised
# Out:
#          logID group                         prep  \
# 0    -6.645391     1                     liposome
# 1    -6.377127     1                     liposome
# 2    -6.032287     2                     liposome
# 3    -3.963316     4                     liposome
# 4    -4.509860     4                     liposome
# ...        ...   ...                          ...
# 1147 -4.039856  1373    solid lipid nanoparticles
# 1148 -3.480598  1376  polymer-based nanoparticles
# 1149 -2.818691  1376  polymer-based nanoparticles
# 1150 -4.480988  1405        albumin nanoparticles
# 1151 -3.882464  1405        albumin nanoparticles
#
#                                  comp  PEG  PEGRatio  surfacecoating  \
# 0                                  pc  0.0       0.0            none
# 1                                dppc  0.0       0.0            none
# 2                                  pc  0.0       0.0            none
# 3                                  pc  0.0       0.0            none
# 4                                  pc  0.0       0.0            none
# ...                               ...  ...       ...             ...
# 1147  gynasan 114/glycerol/lipoid s75  1.0       NaN            none
# 1148                              pcl  0.0       NaN            none
# 1149                          pcl-peg  1.0       5.0            none
# 1150             bovine serum albumin  0.0       NaN            none
# 1151             bovine serum albumin  0.0       NaN  polysorbate 80
#
#      ligandtype                       ligand             mechanism  ...  \
# 0          none                          nan     passive transport  ...
# 1          none                          nan     passive transport  ...
# 2          none                          nan     passive transport  ...
# 3      glycosol           mannose derivative  transporter mediated  ...
# 4      glycosol  fucose\nderivative (l-type)  transporter mediated  ...
# ...         ...                          ...                   ...  ...
# 1147       none                          nan     passive transport  ...
# 1148       none                          nan     passive transport  ...
# 1149       none                          nan     passive transport  ...
# 1150       none                          nan     passive transport  ...
# 1151       none                          nan   absorption mediated  ...
#
#       exact_mass xlogp  tpsa  atom_stereo_count  h_bond_donor_count  \
# 0            NaN   NaN   NaN                NaN                 NaN
# 1            NaN   NaN   NaN                NaN                 NaN
# 2            NaN   NaN   NaN                NaN                 NaN
# 3            NaN   NaN   NaN                NaN                 NaN
# 4            NaN   NaN   NaN                NaN                 NaN
# ...          ...   ...   ...                ...                 ...
# 1147  172.040341   NaN  36.5                0.0                 1.0
# 1148  348.208930   7.6  37.3                0.0                 1.0
# 1149  348.208930   7.6  37.3                0.0                 1.0
# 1150  170.105528  -0.3  63.4                1.0                 1.0
# 1151  170.105528  -0.3  63.4                1.0                 1.0
#
#       h_bond_acceptor_count  rotatable_bond_count  heavy_atom_count  \
# 0                       NaN                   NaN               NaN
# 1                       NaN                   NaN               NaN
# 2                       NaN                   NaN               NaN
# 3                       NaN                   NaN               NaN
# 4                       NaN                   NaN               NaN
# ...                     ...                   ...               ...
# 1147                    3.0                   1.0              11.0
# 1148                    2.0                   3.0              26.0
# 1149                    2.0                   3.0              26.0
# 1150                    2.0                   3.0              12.0
# 1151                    2.0                   3.0              12.0
#
#      complexity xlogp1
# 0           NaN    NaN
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN
# ...         ...    ...
# 1147      125.0    NaN
# 1148      551.0    NaN
# 1149      551.0    NaN
# 1150      203.0    NaN
# 1151      203.0    NaN
#
# [1152 rows x 32 columns]

# %%
#### for i in range(len(data['ligand'])):
    print(str(data['ligand_peptide_length'][i]) + data['ligand'][i])

# %%
cat_df = prep_dataset(data, target_col=target_col, one_hot=False, feat=feat_cols,cat=cat_cols)

study = tune_catboost_with_optuna(
    cat_df=cat_df,
    target_col=target_col,
    cat_cols=cat_cols,
    feat_cols=feat_cols,
    n_trials=50,
    n_splits=5,
)
best_params = study.best_params

results_cat_best = cv_regression_catboost(
    df=cat_df,
    target_col=target_col,
    cat_cols=cat_cols,
    feature_cols=feat_cols,
    use_lmem_cleaning=False,
    cv_type="kfold",
    n_splits=5,
    **best_params,
    rand=42,  # you can still fix a seed if it's not in best_params
)
r2_best = np.mean(results_cat_best["r2_scores"])
print("Final CV r2 with tuned params:", r2_best)

# %%
from GradientBoost import tune_lgbm_with_optuna
'''
study = tune_lgbm_with_optuna(
    lgbm_df=lgbm_df,
    target_col=target_col,
    n_trials=50,
    cv_type="kfold",
    group_col=None,
    n_splits=5,
)

best_params = study.best_params

# 2. Final CV run with best hyperparameters
results_lgbm_best = cv_regression_lgbm(
    df=lgbm_df,
    target_col=target_col,
    cv_type="kfold",
    group_col=None,
    n_splits=5,
    rand=42,          # keep seed fixed
    **best_params,    # n_est, learn, max_d, sub, col
)

r2_best = np.mean(results_lgbm_best["r2_scores"])
print("Final CV r2 with tuned params:", r2_best)'''

# %%
from GradientBoost import tune_ens_with_optuna

study=tune_ens_with_optuna(
    cat_df=cat_df,
    lgbm_df=lgbm_df,
    target_col=target_col,
    cat_cols=cat_cols, 
    n_trials=50,
    cv_type="kfold",
    group_col=None,
    n_splits=5,
)

# %%
models = results_cat['models']
fi = np.mean([model.get_feature_importance() for model in models], axis=0)

# Build dataframe
fi_df = (
    pd.DataFrame({
        "Feature": feat_cols,
        "Importance": fi
    })
    .sort_values("Importance", ascending=False)
    .reset_index(drop=True)
)

fi_df

# %%
dat = pd.read_excel("Brain-Targeted-Nanomedicines-data.xlsx")
data = dat.drop('highest amount in brain/tumor', axis=1)
data = data.rename(columns={'type of the preparation': 'prep', 'core composition of the preparation': 'comp', 'PEGylation or not': 'PEG', 'PEGylation ratio': 'PEGRatio','surface coating': 'surface-coating',  'type of targeting ligand': 'ligand-type', 'targeting ligand': 'ligand', 'transport mechanism': 'mechanism', 'type of receptor/transporter': 'receptor-type', 'name of receptor/transporter': 'receptor', 'p-gp inhibition?': 'Pgp', 'p-gp inhibitor': 'Pgp-inhibitor', 'size （nm）': 'size', 'zeta potantial（mV）': 'zeta', 'encapsulation efficiency（%）': 'EE%', ' DL（g/g）': 'DL', 'animal model': 'animal-model', 'administration route': 'route', 'target ligand density（mol，%）': 'ligand-density-mol', 'target ligand density（number per nanoparticle）': 'ligand-density-num', 'Encapsulation': 'encapsulation', 'laser/magnectic field/radiation': 'external', 'delivering efficiency (% ID)': 'ID%', 'ratio of preparation/free drug': 'delivery-efficiency', 'ratio of modified/unmodified preparation': 'mod-ratio-unmod'})

data.to_csv('datacols.csv', index=False)

# %%
import pandas as pd
import numpy as np
import re

data = pd.read_csv('datacols.csv', index_col=None)

#data = data.drop(['number', 'peak-amt'], axis=1)
newest_no = 0

print(data.columns)


s = pd.Series(data['number'])
data['number'] = s.ffill().tolist()

data['group'] = data['number']
print(data['group'])

def clean_to_numeric(series):
    """
    Converts a pandas Series to numeric by removing units, text,
    and non-numeric characters. Returns floats with NaN for invalid entries.
    """
    # Convert to string
    s = series.astype(str)

    # Remove everything except digits, decimal, minus, +, exponent notation
    s = s.str.replace(r"[^0-9eE+\-\.]", "", regex=True)

    # Convert to numeric
    return pd.to_numeric(s, errors="coerce")

data['size'] = clean_to_numeric(data['size'])
data['zeta'] = clean_to_numeric(data['zeta'])


data.to_csv('datasetCELL2.csv', index=False)
data['size'].dtype, data['zeta'].dtype
